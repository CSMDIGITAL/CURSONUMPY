# %% [markdown]
# ## O que vamos aprender

# %% [markdown]
# - O que e Numpy
# - Manipular arrays (ndarry)
# - indexacao
# - Operacoes vetorizadas
# - Algebra Linear e Estatíticas (Probalidade e Est. Bayesiana)
# - Perfomace: Numpy vs, Listas Nativas Python
# - Boas praticas e solucao do projetos

# %%
print("Thomas Bayes vai revirar do tumulo!")
# Out:
# Thomas Bayes vai revirar do tumulo!

# %% [markdown]
# Porque o Numpy e o caracao  da ciencia de dados em PHTYON
#
# - Pandas
# - Sc
# - TensorFlow (Redes neurais)
# - Matplotlib

# %%
import numpy as np
