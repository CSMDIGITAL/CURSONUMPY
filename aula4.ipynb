# %% [markdown]
# #  Probabilidade e Inteligência Artificial

# %% [markdown]
# - Estatistica e uma area da matematica
# - Probabildiade  e  uma area da estatitica
# - IA Classica  x IA Estatistica

# %% [markdown]
# # Filmes e Series

# %% [markdown]
# - IA Classica: Alan Turing (Jogo da  Imitacao)
# - IA Estatistica

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## IA Clássica (Simbólica e Lógica)

# %% [markdown]
# - O Jogo da Imitação (The Imitation Game): Teoria da Computação, Teste de Turing
# - Ex Machina: Teste de Turing, IA Forte (Intelecto Completo igual ao humano)
# - 2001: Uma Odisseia no Espaço (2001: A Space Odyssey)
# Eu, Robô (I, Robot)
#  - Acompanhamente perfeita
# Blade Runner 2049

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## IA Estatística (Aprendizado de Máquina e Dados)

# %% [markdown]
# Minority Report - A Lei do Futuro
# RoboCop (versão de 2014)
# Moneyball - O Homem que Mudou o Jogo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Conclusao dos Filmes

# %%
import pandas as pd

# %% [markdown]
# Probabilidade e Inteligência Artificial
# Estatística é uma área da matemática
# Probabilidade é uma área da estatística
# IA Classica x IA Estatística
# Filmes e Séries
# IA Classica: Alan Turing o Eu Robô, AI Inteligência Artificial (Jogo da Imitação)
# IA Estatística: Robocop (Consegue prever crimes)
# image.png
#
# IA Clássica (Simbólica e Lógica)
# O Jogo da Imitação (The Imitation Game): Teoria da Computação, Teste de Turing
# Ex Machina: Teste de Turing, IA Forte (Intelecto Completo igual ao humano)
# 2001: Uma Odisseia no Espaço (2001: A Space Odyssey)
# Eu, Robô (I, Robot)
# Acompanhamente perfeita
# Blade Runner 2049
# image.png
#
# IA Estatística (Aprendizado de Máquina e Dados)
# Minority Report - A Lei do Futuro
# RoboCop (versão de 2014)
# Moneyball - O Homem que Mudou o Jogo
# Saiba mais: https://www2.decom.ufop.br/imobilis/fundamentos-de-redes-neurais/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Conclusao dos Filmes
# Os filmes e series devem ser analisados durante as ferias e realizar um relatorio informal
# Estatistica
# Media
# IBGE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Estatística Copa
# Exercício
# Feira dos Goianos

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %% [markdown]
# Quantas pessoas moram próxima feira dos Goianos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ontagem Populacional Agregada
# Andy (Taguatinga)
# Marcos (Ceilandia)
# Wellington (Vicente Pires)
# Vanessa (Sol Nascente e Por do Sol)
# Dennis (Web Scraping)
# Robert (Recanto das Emas)
# David (Riacho Fundo)
# Lucio (Samambaia)
# Nayan (Riacho Fundo II)
# Cada aluno vai propor novas variáveis para nosso DataSet cpa.csv
# Criar uma coluna (variável)
# Inserir informações
# Sugerir coluna x linha (transposição)
# Criar um gráfico de duas colunas (barras)

# %% [markdown]
# ![image.png](attachment:image.png)
